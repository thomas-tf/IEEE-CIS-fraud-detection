# %%
import gc
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFECV
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder

# %%
def rename_test_identity_columns(df):
    """
    Correct test identity columns
    :param df:
    :return df:
    """
    for col in df.columns:
        if col[0:2] == 'id':
            new_col_name = col.split('-')[0] + '_' + col.split('-')[1]
            df = df.rename(columns={col: new_col_name})

    return df


def load_data(DATA_DIRECTORY):
    """
    load training, testing and sample submission files from a given directory
    :param DATA_DIRECTORY:
    :return dataframes:
    """
    train_identity = pd.read_csv(os.path.join(DATA_DIRECTORY, 'train_identity.csv'), index_col='TransactionID')
    train_transaction = pd.read_csv(os.path.join(DATA_DIRECTORY, 'train_transaction.csv'), index_col='TransactionID')

    test_identity = pd.read_csv(os.path.join(DATA_DIRECTORY, 'test_identity.csv'), index_col='TransactionID')
    test_transaction = pd.read_csv(os.path.join(DATA_DIRECTORY, 'test_transaction.csv'), index_col='TransactionID')

    submission = pd.read_csv(os.path.join(DATA_DIRECTORY, 'sample_submission.csv'))

    return train_identity, train_transaction, rename_test_identity_columns(test_identity), test_transaction, submission

# %%
def reduce_mem_usage(df, verbose=True):
    """
    reduce memory usage by casting datatype to lower bits
    :param df:
    :param verbose:
    :return df:
    """
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:

        col_type = df[col].dtypes

        if col_type in numerics:

            c_min = df[col].min()
            c_max = df[col].max()

            if str(col_type)[:3] == 'int':

                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)

            else:

                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024 ** 2

    if verbose:
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(
            end_mem, 100 * (start_mem - end_mem) / start_mem)
        )
    return df


def label_encoding(df):
    for col in tqdm(df.columns, desc="Label Encoding..."):
        if df[col].dtype == 'object':
            le = LabelEncoder()
            le.fit(list(df[col].astype(str).values) + list(df[col].astype(str).values))
            df[col] = le.transform(list(df[col].astype(str).values))


def recursive_feature_elimination(train, from_backup=True):
    """
    conduct recursive feature elimination on the given training dataset
    :param train: training dataset
    :param from_backup: load from historical result (stored as list of strings), defaults to True
    :return top ranked features:
    """
    # defaults to return backup list
    if from_backup:
        return ['TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2',
                'dist1', 'P_emaildomain', 'R_emaildomain', 'C1', 'C2', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11',
                'C12', 'C13', 'C14', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D8', 'D9', 'D10', 'D11', 'D12', 'D13', 'D14',
                'D15', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'V3', 'V4', 'V5', 'V7', 'V12', 'V13', 'V19',
                'V20', 'V29', 'V30', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V40', 'V43', 'V44', 'V45', 'V47', 'V48',
                'V49', 'V51', 'V52', 'V53', 'V54', 'V56', 'V57', 'V58', 'V60', 'V61', 'V62', 'V69', 'V70', 'V72', 'V74',
                'V75', 'V76', 'V78', 'V81', 'V82', 'V83', 'V87', 'V90', 'V91', 'V94', 'V95', 'V96', 'V97', 'V99',
                'V100', 'V126', 'V127', 'V128', 'V130', 'V131', 'V139', 'V140', 'V143', 'V145', 'V149', 'V150', 'V152',
                'V156', 'V158', 'V159', 'V160', 'V162', 'V164', 'V165', 'V166', 'V167', 'V169', 'V170', 'V171', 'V187',
                'V188', 'V189', 'V200', 'V201', 'V202', 'V203', 'V204', 'V205', 'V206', 'V207', 'V208', 'V209', 'V210',
                'V212', 'V213', 'V215', 'V216', 'V217', 'V218', 'V219', 'V221', 'V222', 'V223', 'V224', 'V225', 'V226',
                'V228', 'V231', 'V232', 'V233', 'V234', 'V243', 'V244', 'V251', 'V254', 'V256', 'V257', 'V258', 'V261',
                'V262', 'V263', 'V264', 'V265', 'V266', 'V267', 'V268', 'V270', 'V271', 'V272', 'V273', 'V274', 'V275',
                'V276', 'V277', 'V278', 'V279', 'V280', 'V282', 'V283', 'V285', 'V287', 'V288', 'V289', 'V291', 'V292',
                'V294', 'V303', 'V306', 'V307', 'V308', 'V310', 'V312', 'V313', 'V314', 'V315', 'V317', 'V322', 'V323',
                'V324', 'V326', 'V331', 'V332', 'V333', 'V335', 'id_01', 'id_02', 'id_03', 'id_05', 'id_06', 'id_09',
                'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_19', 'id_20', 'id_30', 'id_31', 'id_32', 'id_33',
                'id_38', 'DeviceType', 'DeviceInfo', 'device_name', 'OS_id_30', 'version_id_30', 'browser_id_31',
                'version_id_31', 'screen_width', 'screen_height', 'P_emaildomain_bin', 'P_emaildomain_suffix',
                'R_emaildomain_bin', 'R_emaildomain_suffix', 'TransactionAmt_Log', 'TransactionAmt_decimal']

        # if desire to conduct RFE again...
    train = reduce_mem_usage(train)

    X = train.sort_values('TransactionDT').drop(['isFraud', 'TransactionDT'], axis=1)
    y = train.sort_values('TransactionDT')['isFraud']

    del train
    gc.collect()

    X.fillna(-999, inplace=True)

    # parameters chosen by BayesianOptimization
    # Credit to this notebook: https://www.kaggle.com/vincentlugat/ieee-lgb-bayesian-opt/notebook
    params = {
        'num_leaves': 491,
        'min_child_weight': 0.03454472573214212,
        'feature_fraction': 0.3797454081646243,
        'bagging_fraction': 0.4181193142567742,
        'min_data_in_leaf': 106,
        'objective': 'binary',
        'max_depth': -1,
        'learning_rate': 0.006883242363721497,
        "boosting_type": "gbdt",
        "bagging_seed": 11,
        "metric": 'auc',
        "verbosity": -1,
        'reg_alpha': 0.3899927210061127,
        'reg_lambda': 0.6485237330340494,
        'random_state': 47
    }

    import lightgbm as lgb

    clf = lgb.LGBMClassifier(**params)
    rfe = RFECV(estimator=clf, step=10, cv=KFold(n_splits=5, shuffle=False), scoring='roc_auc', verbose=2)

    rfe.fit(X, y)

    return X.columns[rfe.ranking_ == 1].tolist()

# %%
DATA_DIRECTORY = '../input/ieee-fraud-detection/'


def id_split(df):
    """
    Split or convert some identifiable features in subsets
    :param df:
    :return df:
    """
    df['device_name'] = df['DeviceInfo'].str.split('/', expand=True)[0]
    df['device_version'] = df['DeviceInfo'].str.split('/', expand=True)[1]

    df['OS_id_30'] = df['id_30'].str.split(' ', expand=True)[0]
    df['version_id_30'] = df['id_30'].str.split(' ', expand=True)[1]

    df['browser_id_31'] = df['id_31'].str.split(' ', expand=True)[0]
    df['version_id_31'] = df['id_31'].str.split(' ', expand=True)[1]

    df['screen_width'] = df['id_33'].str.split('x', expand=True)[0]
    df['screen_height'] = df['id_33'].str.split('x', expand=True)[1]

    df['id_34'] = df['id_34'].str.split(':', expand=True)[1]
    df['id_23'] = df['id_23'].str.split(':', expand=True)[1]

    df.loc[df['device_name'].str.contains('SM', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('SAMSUNG', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('GT-', na=False), 'device_name'] = 'Samsung'
    df.loc[df['device_name'].str.contains('Moto G', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('Moto', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('moto', na=False), 'device_name'] = 'Motorola'
    df.loc[df['device_name'].str.contains('LG-', na=False), 'device_name'] = 'LG'
    df.loc[df['device_name'].str.contains('rv:', na=False), 'device_name'] = 'RV'
    df.loc[df['device_name'].str.contains('HUAWEI', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('ALE-', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('-L', na=False), 'device_name'] = 'Huawei'
    df.loc[df['device_name'].str.contains('Blade', na=False), 'device_name'] = 'ZTE'
    df.loc[df['device_name'].str.contains('BLADE', na=False), 'device_name'] = 'ZTE'
    df.loc[df['device_name'].str.contains('Linux', na=False), 'device_name'] = 'Linux'
    df.loc[df['device_name'].str.contains('XT', na=False), 'device_name'] = 'Sony'
    df.loc[df['device_name'].str.contains('HTC', na=False), 'device_name'] = 'HTC'
    df.loc[df['device_name'].str.contains('ASUS', na=False), 'device_name'] = 'Asus'

    df.loc[df.device_name.isin(df.device_name.value_counts()[
                                   df.device_name.value_counts() < 200].index), 'device_name'] = "Others"
    df['had_id'] = 1
    gc.collect()

    return df


def merge_transaction_and_identify(transaction, identity):
    df = transaction.merge(identity, how='left', left_index=True, right_index=True)

    del transaction, identity

    gc.collect()

    return df


def email_mappings(train, test):
    """
    group email domains to company
    yahoo / ymail / frontier / rocketmail -> Yahoo
    hotmail / outlook / live / msn -> Microsoft
    icloud / mac / me -> Appe
    prodigy / att / sbcglobal-> AT&T
    centurylink / embarqmail / q -> Centurylink
    aim / aol -> AOL
    twc / charter -> Spectrum
    :param train:
    :param test:
    :return train, test:
    """
    emails = {'gmail': 'google', 'att.net': 'att', 'twc.com': 'spectrum', 'scranton.edu': 'other',
              'optonline.net': 'other', 'hotmail.co.uk': 'microsoft', 'comcast.net': 'other', 'yahoo.com.mx': 'yahoo',
              'yahoo.fr': 'yahoo', 'yahoo.es': 'yahoo', 'charter.net': 'spectrum', 'live.com': 'microsoft',
              'aim.com': 'aol', 'hotmail.de': 'microsoft', 'centurylink.net': 'centurylink', 'gmail.com': 'google',
              'me.com': 'apple', 'earthlink.net': 'other', 'gmx.de': 'other', 'web.de': 'other', 'cfl.rr.com': 'other',
              'hotmail.com': 'microsoft', 'protonmail.com': 'other', 'hotmail.fr': 'microsoft',
              'windstream.net': 'other', 'outlook.es': 'microsoft', 'yahoo.co.jp': 'yahoo', 'yahoo.de': 'yahoo',
              'servicios-ta.com': 'other', 'netzero.net': 'other', 'suddenlink.net': 'other', 'roadrunner.com': 'other',
              'sc.rr.com': 'other', 'live.fr': 'microsoft', 'verizon.net': 'yahoo', 'msn.com': 'microsoft',
              'q.com': 'centurylink', 'prodigy.net.mx': 'att', 'frontier.com': 'yahoo', 'anonymous.com': 'other',
              'rocketmail.com': 'yahoo', 'sbcglobal.net': 'att', 'frontiernet.net': 'yahoo', 'ymail.com': 'yahoo',
              'outlook.com': 'microsoft', 'mail.com': 'other', 'bellsouth.net': 'other',
              'embarqmail.com': 'centurylink', 'cableone.net': 'other', 'hotmail.es': 'microsoft', 'mac.com': 'apple',
              'yahoo.co.uk': 'yahoo', 'netzero.com': 'other', 'yahoo.com': 'yahoo', 'live.com.mx': 'microsoft',
              'ptd.net': 'other', 'cox.net': 'other', 'aol.com': 'aol', 'juno.com': 'other', 'icloud.com': 'apple'}

    us_emails = ['gmail', 'net', 'edu']

    for c in ['P_emaildomain', 'R_emaildomain']:
        train[c + '_bin'] = train[c].map(emails)
        test[c + '_bin'] = test[c].map(emails)

        train[c + '_suffix'] = train[c].map(lambda x: str(x).split('.')[-1])
        test[c + '_suffix'] = test[c].map(lambda x: str(x).split('.')[-1])

        train[c + '_suffix'] = train[c + '_suffix'].map(lambda x: x if str(x) not in us_emails else 'us')
        test[c + '_suffix'] = test[c + '_suffix'].map(lambda x: x if str(x) not in us_emails else 'us')

    return train, test


def transaction_amt_features(train, test):
    """
    generate features on base on transaction amount
    :param train:
    :param test:
    :return train, test:
    """
    # log transformation
    train['TransactionAmt_Log'] = np.log(train['TransactionAmt'])
    test['TransactionAmt_Log'] = np.log(test['TransactionAmt'])

    # get decimal part as feature
    train['TransactionAmt_decimal'] = ((train['TransactionAmt'] - train['TransactionAmt'].astype(int)) * 1000).astype(
        int)
    test['TransactionAmt_decimal'] = ((test['TransactionAmt'] - test['TransactionAmt'].astype(int)) * 1000).astype(int)

    return train, test


def drop_useless_columns(train, test):
    """
    drop columns if:
    - only 1 category
    - More than 90% of the values are NaN
    - More than 90% of the values are the same
    :param train:
    :param test:
    :return train, test:
    """
    one_value_cols = [col for col in train.columns if train[col].nunique() <= 1]
    one_value_cols_test = [col for col in test.columns if test[col].nunique() <= 1]

    many_null_cols = [col for col in train.columns if train[col].isnull().sum() / train.shape[0] > 0.9]
    many_null_cols_test = [col for col in test.columns if test[col].isnull().sum() / test.shape[0] > 0.9]

    big_top_value_cols = [col for col in train.columns if
                          train[col].value_counts(dropna=False, normalize=True).values[0] > 0.9]
    big_top_value_cols_test = [col for col in test.columns if
                               test[col].value_counts(dropna=False, normalize=True).values[0] > 0.9]

    cols_to_drop = list(set(
        many_null_cols +
        many_null_cols_test +
        big_top_value_cols +
        big_top_value_cols_test +
        one_value_cols +
        one_value_cols_test
    ))

    # exclude target
    cols_to_drop.remove('isFraud')

    train = train.drop(cols_to_drop, axis=1)
    test = test.drop(cols_to_drop, axis=1)

    return train, test


def top_features_aggregation(train, test):
    """
    aggregate top ranked features (by RFE)
    :param train:
    :param test:
    :return train, test:
    """
    columns_a = ['TransactionAmt', 'id_02', 'D15']
    columns_b = ['card1', 'card4', 'addr1']

    for col_a in columns_a:
        for col_b in columns_b:
            for df in [train, test]:
                df[f'{col_a}_to_mean_{col_b}'] = df[col_a] / df.groupby([col_b])[col_a].transform('mean')
                df[f'{col_a}_to_std_{col_b}'] = df[col_a] / df.groupby([col_b])[col_a].transform('std')

    return train, test


def label_encoding(train, test):
    """
    Label encode categorical columns
    :param train:
    :param test:
    :return:
    """
    for col in train.columns:
        if train[col].dtype == 'object':
            le = LabelEncoder()
            le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
            train[col] = le.transform(list(train[col].astype(str).values))
            test[col] = le.transform(list(test[col].astype(str).values))

    return train, test


def clean_inf_nan(df):
    """
    replace infs to nan
    reference: https://www.kaggle.com/dimartinot
    :param df:
    :return df:
    """
    return df.replace([np.inf, -np.inf], np.nan)


def feature_engineering():
    """
    load original datasets and conduct feature engineering
    :return X_train, y_train, X_test, submission:
    """
    train_identity, train_transaction, test_identity, test_transaction, submission = load_data(DATA_DIRECTORY)

    train_identity = id_split(train_identity)
    test_identity = id_split(test_identity)

    train = merge_transaction_and_identify(train_transaction, train_identity)
    test = merge_transaction_and_identify(test_transaction, test_identity)

    train, test = email_mappings(train, test)

    train, test = drop_useless_columns(train, test)
    
    train, test = transaction_amt_features(train, test)

    useful_features = recursive_feature_elimination(train)

    cols_to_drop = [col for col in train.columns if col not in useful_features]
    cols_to_drop.remove('isFraud')
    cols_to_drop.remove('TransactionDT')

    train = train.drop(cols_to_drop, axis=1)
    test = test.drop(cols_to_drop, axis=1)

    train, test = label_encoding(train, test)

    X_train = train.sort_values('TransactionDT').drop(['isFraud', 'TransactionDT'], axis=1)
    y_train = train.sort_values('TransactionDT')['isFraud']

    X_test = test.drop(['TransactionDT'], axis=1)

    del train, test
    gc.collect()

    X_train = clean_inf_nan(X_train)
    X_test = clean_inf_nan(X_test)

    return X_train, y_train, X_test, submission

# %%
X_train, y_train, X_test, sample_submission = feature_engineering()

# %%
X_train.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Data columns (total 242 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionAmt          590540 non-null  float64
#  1   ProductCD               590540 non-null  int64
#  2   card1                   590540 non-null  int64
#  3   card2                   581607 non-null  float64
#  4   card3                   588975 non-null  float64
#  5   card4                   590540 non-null  int64
#  6   card5                   586281 non-null  float64
#  7   card6                   590540 non-null  int64
#  8   addr1                   524834 non-null  float64
#  9   addr2                   524834 non-null  float64
#  10  dist1                   238269 non-null  float64
#  11  P_emaildomain           590540 non-null  int64
#  12  R_emaildomain           590540 non-null  int64
#  13  C1                      590540 non-null  float64
#  14  C2                      590540 non-null  float64
#  15  C4                      590540 non-null  float64
#  16  C5                      590540 non-null  float64
#  17  C6                      590540 non-null  float64
#  18  C7                      590540 non-null  float64
#  19  C8                      590540 non-null  float64
#  20  C9                      590540 non-null  float64
#  21  C10                     590540 non-null  float64
#  22  C11                     590540 non-null  float64
#  23  C12                     590540 non-null  float64
#  24  C13                     590540 non-null  float64
#  25  C14                     590540 non-null  float64
#  26  D1                      589271 non-null  float64
#  27  D2                      309743 non-null  float64
#  28  D3                      327662 non-null  float64
#  29  D4                      421618 non-null  float64
#  30  D5                      280699 non-null  float64
#  31  D6                      73187 non-null   float64
#  118 V165                    81951 non-null   float64
#  119 V166                    81951 non-null   float64
#  120 V167                    139631 non-null  float64
#  121 V169                    139819 non-null  float64
#  122 V170                    139819 non-null  float64
#  123 V171                    139819 non-null  float64
#  124 V187                    139631 non-null  float64
#  125 V188                    139819 non-null  float64
#  126 V189                    139819 non-null  float64
#  127 V200                    139819 non-null  float64
#  128 V201                    139819 non-null  float64
#  129 V202                    139631 non-null  float64
#  130 V203                    139631 non-null  float64
#  131 V204                    139631 non-null  float64
#  132 V205                    139631 non-null  float64
#  133 V206                    139631 non-null  float64
#  134 V207                    139631 non-null  float64
#  135 V208                    139819 non-null  float64
#  136 V209                    139819 non-null  float64
#  137 V210                    139819 non-null  float64
#  138 V212                    139631 non-null  float64
#  139 V213                    139631 non-null  float64
#  140 V215                    139631 non-null  float64
#  141 V216                    139631 non-null  float64
#  142 V217                    130430 non-null  float64
#  143 V218                    130430 non-null  float64
#  144 V219                    130430 non-null  float64
#  145 V221                    141416 non-null  float64
#  146 V222                    141416 non-null  float64
#  147 V223                    130430 non-null  float64
#  148 V224                    130430 non-null  float64
#  149 V225                    130430 non-null  float64
#  150 V226                    130430 non-null  float64
#  151 V228                    130430 non-null  float64
#  152 V231                    130430 non-null  float64
#  153 V232                    130430 non-null  float64
#  154 V233                    130430 non-null  float64
#  155 V234                    141416 non-null  float64
#  156 V243                    130430 non-null  float64
#  157 V244                    130430 non-null  float64
#  158 V251                    141416 non-null  float64
#  159 V254                    130430 non-null  float64
#  160 V256                    141416 non-null  float64
#  161 V257                    130430 non-null  float64
#  162 V258                    130430 non-null  float64
#  163 V261                    130430 non-null  float64
#  164 V262                    130430 non-null  float64
#  165 V263                    130430 non-null  float64
#  166 V264                    130430 non-null  float64
#  167 V265                    130430 non-null  float64
#  168 V266                    130430 non-null  float64
#  169 V267                    130430 non-null  float64
#  170 V268                    130430 non-null  float64
#  171 V270                    141416 non-null  float64
#  172 V271                    141416 non-null  float64
#  173 V272                    141416 non-null  float64
#  174 V273                    130430 non-null  float64
#  175 V274                    130430 non-null  float64
#  176 V275                    130430 non-null  float64
#  177 V276                    130430 non-null  float64
#  178 V277                    130430 non-null  float64
#  179 V278                    130430 non-null  float64
#  180 V279                    590528 non-null  float64
#  181 V280                    590528 non-null  float64
#  182 V282                    589271 non-null  float64
#  183 V283                    589271 non-null  float64
#  184 V285                    590528 non-null  float64
#  185 V287                    590528 non-null  float64
#  186 V288                    589271 non-null  float64
#  187 V289                    589271 non-null  float64
#  188 V291                    590528 non-null  float64
#  189 V292                    590528 non-null  float64
#  190 V294                    590528 non-null  float64
#  191 V303                    590528 non-null  float64
#  192 V306                    590528 non-null  float64
#  193 V307                    590528 non-null  float64
#  194 V308                    590528 non-null  float64
#  195 V310                    590528 non-null  float64
#  196 V312                    590528 non-null  float64
#  197 V313                    589271 non-null  float64
#  198 V314                    589271 non-null  float64
#  199 V315                    589271 non-null  float64
#  200 V317                    590528 non-null  float64
#  201 V322                    82351 non-null   float64
#  202 V323                    82351 non-null   float64
#  203 V324                    82351 non-null   float64
#  204 V326                    82351 non-null   float64
#  205 V331                    82351 non-null   float64
#  206 V332                    82351 non-null   float64
#  207 V333                    82351 non-null   float64
#  208 V335                    82351 non-null   float64
#  209 id_01                   144233 non-null  float64
#  210 id_02                   140872 non-null  float64
#  211 id_03                   66324 non-null   float64
#  212 id_05                   136865 non-null  float64
#  213 id_06                   136865 non-null  float64
#  214 id_09                   74926 non-null   float64
#  215 id_13                   127320 non-null  float64
#  216 id_14                   80044 non-null   float64
#  217 id_15                   590540 non-null  int64
#  218 id_16                   590540 non-null  int64
#  219 id_17                   139369 non-null  float64
#  220 id_19                   139318 non-null  float64
#  221 id_20                   139261 non-null  float64
#  222 id_30                   590540 non-null  int64
#  223 id_31                   590540 non-null  int64
#  224 id_32                   77586 non-null   float64
#  225 id_33                   590540 non-null  int64
#  226 id_38                   590540 non-null  int64
#  227 DeviceType              590540 non-null  int64
#  228 DeviceInfo              590540 non-null  int64
#  229 device_name             590540 non-null  int64
#  230 OS_id_30                590540 non-null  int64
#  231 version_id_30           590540 non-null  int64
#  232 browser_id_31           590540 non-null  int64
#  233 version_id_31           590540 non-null  int64
#  234 screen_width            590540 non-null  int64
#  235 screen_height           590540 non-null  int64
#  236 P_emaildomain_bin       590540 non-null  int64
#  237 P_emaildomain_suffix    590540 non-null  int64
#  238 R_emaildomain_bin       590540 non-null  int64
#  239 R_emaildomain_suffix    590540 non-null  int64
#  240 TransactionAmt_Log      590540 non-null  float64
#  241 TransactionAmt_decimal  590540 non-null  int64
# dtypes: float64(208), int64(34)
# memory usage: 1.1 GB

# %%
X_train.fillna(-999, inplace=True)

# %%
X_train.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Data columns (total 242 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionAmt          590540 non-null  float64
#  1   ProductCD               590540 non-null  int64
#  2   card1                   590540 non-null  int64
#  3   card2                   590540 non-null  float64
#  4   card3                   590540 non-null  float64
#  5   card4                   590540 non-null  int64
#  6   card5                   590540 non-null  float64
#  7   card6                   590540 non-null  int64
#  8   addr1                   590540 non-null  float64
#  9   addr2                   590540 non-null  float64
#  10  dist1                   590540 non-null  float64
#  11  P_emaildomain           590540 non-null  int64
#  12  R_emaildomain           590540 non-null  int64
#  13  C1                      590540 non-null  float64
#  14  C2                      590540 non-null  float64
#  15  C4                      590540 non-null  float64
#  16  C5                      590540 non-null  float64
#  17  C6                      590540 non-null  float64
#  18  C7                      590540 non-null  float64
#  19  C8                      590540 non-null  float64
#  20  C9                      590540 non-null  float64
#  21  C10                     590540 non-null  float64
#  22  C11                     590540 non-null  float64
#  23  C12                     590540 non-null  float64
#  24  C13                     590540 non-null  float64
#  25  C14                     590540 non-null  float64
#  26  D1                      590540 non-null  float64
#  27  D2                      590540 non-null  float64
#  28  D3                      590540 non-null  float64
#  29  D4                      590540 non-null  float64
#  30  D5                      590540 non-null  float64
#  31  D6                      590540 non-null  float64
#  32  D8                      590540 non-null  float64
#  33  D9                      590540 non-null  float64
#  34  D10                     590540 non-null  float64
#  35  D11                     590540 non-null  float64
#  36  D12                     590540 non-null  float64
#  37  D13                     590540 non-null  float64
#  38  D14                     590540 non-null  float64
#  211 id_03                   590540 non-null  float64
#  212 id_05                   590540 non-null  float64
#  213 id_06                   590540 non-null  float64
#  214 id_09                   590540 non-null  float64
#  215 id_13                   590540 non-null  float64
#  216 id_14                   590540 non-null  float64
#  217 id_15                   590540 non-null  int64
#  218 id_16                   590540 non-null  int64
#  219 id_17                   590540 non-null  float64
#  220 id_19                   590540 non-null  float64
#  221 id_20                   590540 non-null  float64
#  222 id_30                   590540 non-null  int64
#  223 id_31                   590540 non-null  int64
#  224 id_32                   590540 non-null  float64
#  225 id_33                   590540 non-null  int64
#  226 id_38                   590540 non-null  int64
#  227 DeviceType              590540 non-null  int64
#  228 DeviceInfo              590540 non-null  int64
#  229 device_name             590540 non-null  int64
#  230 OS_id_30                590540 non-null  int64
#  231 version_id_30           590540 non-null  int64
#  232 browser_id_31           590540 non-null  int64
#  233 version_id_31           590540 non-null  int64
#  234 screen_width            590540 non-null  int64
#  235 screen_height           590540 non-null  int64
#  236 P_emaildomain_bin       590540 non-null  int64
#  237 P_emaildomain_suffix    590540 non-null  int64
#  238 R_emaildomain_bin       590540 non-null  int64
#  239 R_emaildomain_suffix    590540 non-null  int64
#  240 TransactionAmt_Log      590540 non-null  float64
#  241 TransactionAmt_decimal  590540 non-null  int64
# dtypes: float64(208), int64(34)
# memory usage: 1.1 GB

# %%
## List of categorical variables according to data description
id_cat_var = ['ProductCD', 'addr1', 'addr2', 'P_emaildomain', 'R_emaildomain'] + ['card' + str(i) for i in range(1,7)] + ['M' + str(i) for i in range(1,10)]
tran_cat_var = ['DeviceType', 'DeviceInfo'] + ['id_' + str(i) for i in range(12,39)]

## List of categorical variables derived from the original dataset
der_cat_var = ['device_name','OS_id_30','version_id_30','browser_id_31','version_id_31','P_emaildomain_bin','P_emaildomain_suffix','R_emaildomain_bin','R_emaildomain_suffix']

cat_var = id_cat_var + tran_cat_var + der_cat_var

# %%
cat_var_new = ['isFraud']

for var in cat_var:
    if var in X_train.columns.tolist():
        cat_var_new.append(var)

# %%
cat_var_new
# Out:
# ['isFraud',
#  'ProductCD',
#  'addr1',
#  'addr2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'card1',
#  'card2',
#  'card3',
#  'card4',
#  'card5',
#  'card6',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'DeviceType',
#  'DeviceInfo',
#  'id_13',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_19',
#  'id_20',
#  'id_30',
#  'id_31',
#  'id_32',
#  'id_33',
#  'id_38',
#  'device_name',
#  'OS_id_30',
#  'version_id_30',
#  'browser_id_31',
#  'version_id_31',
#  'P_emaildomain_bin',
#  'P_emaildomain_suffix',
#  'R_emaildomain_bin',
#  'R_emaildomain_suffix']

# %%
training = pd.merge(X_train, y_train, on='TransactionID')

# %%
training.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 590540 entries, 2987000 to 3577539
# Data columns (total 243 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Transact
#  177 V276                    590540 non-null  float64
#  178 V277                    590540 non-null  float64
#  179 V278                    590540 non-null  float64
#  180 V279                    590540 non-null  float64
#  181 V280                    590540 non-null  float64
#  182 V282                    590540 non-null  float64
#  183 V283                    590540 non-null  float64
#  184 V285                    590540 non-null  float64
#  185 V287                    590540 non-null  float64
#  186 V288                    590540 non-null  float64
#  187 V289                    590540 non-null  float64
#  188 V291                    590540 non-null  float64
#  189 V292                    590540 non-null  float64
#  190 V294                    590540 non-null  float64
#  191 V303                    590540 non-null  float64
#  192 V306                    590540 non-null  float64
#  193 V307                    590540 non-null  float64
#  194 V308                    590540 non-null  float64
#  195 V310                    590540 non-null  float64
#  196 V312                    590540 non-null  float64
#  197 V313                    590540 non-null  float64
#  198 V314                    590540 non-null  float64
#  199 V315                    590540 non-null  float64
#  200 V317                    590540 non-null  float64
#  201 V322                    590540 non-null  float64
#  202 V323                    590540 non-null  float64
#  203 V324                    590540 non-null  float64
#  204 V326                    590540 non-null  float64
#  205 V331                    590540 non-null  float64
#  206 V332                    590540 non-null  float64
#  207 V333                    590540 non-null  float64
#  208 V335                    590540 non-null  float64
#  209 id_01                   590540 non-null  float64
#  210 id_02                   590540 non-null  float64
#  211 id_03                   590540 non-null  float64
#  212 id_05                   590540 non-null  float64
#  213 id_06                   590540 non-null  float64
#  214 id_09                   590540 non-null  float64
#  215 id_13                   590540 non-null  float64
#  216 id_14                   590540 non-null  float64
#  217 id_15                   590540 non-null  int64
#  218 id_16                   590540 non-null  int64
#  219 id_17                   590540 non-null  float64
#  220 id_19                   590540 non-null  float64
#  221 id_20                   590540 non-null  float64
#  222 id_30                   590540 non-null  int64
#  223 id_31                   590540 non-null  int64
#  224 id_32                   590540 non-null  float64
#  225 id_33                   590540 non-null  int64
#  226 id_38                   590540 non-null  int64
#  227 DeviceType              590540 non-null  int64
#  228 DeviceInfo              590540 non-null  int64
#  229 device_name             590540 non-null  int64
#  230 OS_id_30                590540 non-null  int64
#  231 version_id_30           590540 non-null  int64
#  232 browser_id_31           590540 non-null  int64
#  233 version_id_31           590540 non-null  int64
#  234 screen_width            590540 non-null  int64
#  235 screen_height           590540 non-null  int64
#  236 P_emaildomain_bin       590540 non-null  int64
#  237 P_emaildomain_suffix    590540 non-null  int64
#  238 R_emaildomain_bin       590540 non-null  int64
#  239 R_emaildomain_suffix    590540 non-null  int64
#  240 TransactionAmt_Log      590540 non-null  float64
#  241 TransactionAmt_decimal  590540 non-null  int64
#  242 isFraud                 590540 non-null  int64
# dtypes: float64(208), int64(35)
# memory usage: 1.1 GB

# %%
del X_train, y_train

# %%
import h2o
from h2o.estimators.random_forest import H2ORandomForestEstimator

# %%
h2o.init()
h2o.cluster().show_status()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.9.1" 2020-11-04; OpenJDK Runtime Environment (build 11.0.9.1+1-Ubuntu-0ubuntu1.18.04); OpenJDK 64-Bit Server VM (build 11.0.9.1+1-Ubuntu-0ubuntu1.18.04, mixed mode, sharing)
#   Starting server from /opt/conda/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp202u687h
#   JVM stdout: /tmp/tmp202u687h/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp202u687h/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# H2O_cluster_version_age:    2 months and 3 days
# H2O_cluster_name:           H2O_from_python_unknownUser_ni27s0
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.6 final
# --------------------------  ------------------------------------------------------------------
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# H2O_cluster_version_age:    2 months and 3 days
# H2O_cluster_name:           H2O_from_python_unknownUser_ni27s0
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.6 final
# --------------------------  ------------------------------------------------------------------

# %%
training_hf = h2o.H2OFrame(training)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
for var in cat_var_new:
    training_hf[var] = training_hf[var].asfactor()

# %%
training_hf.types
# Out:
# {'TransactionAmt': 'real',
#  'ProductCD': 'enum',
#  'card1': 'enum',
#  'card2': 'enum',
#  'card3': 'enum',
#  'card4': 'enum',
#  'card5': 'enum',
#  'card6': 'enum',
#  'addr1': 'enum',
#  'addr2': 'enum',
#  'dist1': 'int',
#  'P_emaildomain': 'enum',
#  'R_emaildomain': 'enum',
#  'C1': 'int',
#  'C2': 'int',
#  'C4': 'int',
#  'C5': 'int',
#  'C6': 'int',
#  'C7': 'int',
#  'C8': 'int',
#  'C9': 'int',
#  'C10': 'int',
#  'C11': 'int',
#  'C12': 'int',
#  'C13': 'int',
#  'C14': 'int',
#  'D1': 'int',
#  'D2': 'int',
#  'D3': 'int',
#  'D4': 'int',
#  'D5': 'int',
#  'D6': 'int',
#  'D8': 'real',
#  'D9': 'real',
#  'D10': 'int',
#  'D11': 'int',
#  'D12': 'int',
#  'D13': 'int',
#  'D14': 'int',
#  'D15': 'int',
#  'M2': 'enum',
#  'M3': 'enum',
#  'M4': 'enum',
#  'M5': 'enum',
#  'M6': 'enum',
#  'M7': 'enum',
#  'M8': 'enum',
#  'M9': 'enum',
#  'V3': 'int',
#  'V4': 'int',
#  'V5': 'int',
#  'V7': 'int',
#  'V12': 'int',
#  'V13': 'int',
#  'V19': 'int',
#  'V20': 'int',
#  'V29': 'int',
#  'V30': 'int',
#  'V33': 'int',
#  'V34': 'int',
#  'V35': 'int',
#  'V36': 'int',
#  'V37': 'int',
#  'V38': 'int',
#  'V40': 'int',
#  'V43': 'int',
#  'V44': 'int',
#  'V45': 'int',
#  'V47': 'int',
#  'V48': 'int',
#  'V49': 'int',
#  'V51': 'int',
#  'V52': 'int',
#  'V53': 'int',
#  'V54': 'int',
#  'V56': 'int',
#  'V57': 'int',
#  'V58': 'int',
#  'V60': 'int',
#  'V61': 'int',
#  'V62': 'int',
#  'V69': 'int',
#  'V70': 'int',
#  'V72': 'int',
#  'V74': 'int',
#  'V75': 'int',
#  'V76': 'int',
#  'V78': 'int',
#  'V81': 'int',
#  'V82': 'int',
#  'V83': 'int',
#  'V87': 'int',
#  'V90': 'int',
#  'V91': 'int',
#  'V94': 'int',
#  'V95': 'int',
#  'V96': 'int',
#  'V97': 'int',
#  'V99': 'int',
#  'V100': 'int',
#  'V126': 'real',
#  'V127': 'real',
#  'V128': 'real',
#  'V130': 'real',
#  'V131': 'real',
#  'V139': 'int',
#  'V140': 'int',
#  'V143': 'int',
#  'V145': 'int',
#  'V149': 'int',
#  'V150': 'int',
#  'V152': 'int',
#  'V156': 'int',
#  'V158': 'int',
#  'V159': 'real',
#  'V160': 'real',
#  'V162': 'real',
#  'V164': 'real',
#  'V165': 'real',
#  'V166': 'real',
#  'V167': 'int',
#  'V169': 'int',
#  'V170': 'int',
#  'V171': 'int',
#  'V187': 'int',
#  'V188': 'int',
#  'V189': 'int',
#  'V200': 'int',
#  'V201': 'int',
#  'V202': 'real',
#  'V203': 'real',
#  'V204': 'real',
#  'V205': 'real',
#  'V206': 'real',
#  'V207': 'real',
#  'V208': 'real',
#  'V209': 'real',
#  'V210': 'real',
#  'V212': 'real',
#  'V213': 'real',
#  'V215': 'real',
#  'V216': 'real',
#  'V217': 'int',
#  'V218': 'int',
#  'V219': 'int',
#  'V221': 'int',
#  'V222': 'int',
#  'V223': 'int',
#  'V224': 'int',
#  'V225': 'int',
#  'V226': 'int',
#  'V228': 'int',
#  'V231': 'int',
#  'V232': 'int',
#  'V233': 'int',
#  'V234': 'int',
#  'V243': 'int',
#  'V244': 'int',
#  'V251': 'int',
#  'V254': 'int',
#  'V256': 'int',
#  'V257': 'int',
#  'V258': 'int',
#  'V261': 'int',
#  'V262': 'int',
#  'V263': 'real',
#  'V264': 'real',
#  'V265': 'real',
#  'V266': 'real',
#  'V267': 'real',
#  'V268': 'real',
#  'V270': 'real',
#  'V271': 'real',
#  'V272': 'real',
#  'V273': 'real',
#  'V274': 'real',
#  'V275': 'real',
#  'V276': 'real',
#  'V277': 'real',
#  'V278': 'real',
#  'V279': 'int',
#  'V280': 'int',
#  'V282': 'int',
#  'V283': 'int',
#  'V285': 'int',
#  'V287': 'int',
#  'V288': 'int',
#  'V289': 'int',
#  'V291': 'int',
#  'V292': 'int',
#  'V294': 'int',
#  'V303': 'int',
#  'V306': 'real',
#  'V307': 'real',
#  'V308': 'real',
#  'V310': 'real',
#  'V312': 'real',
#  'V313': 'real',
#  'V314': 'real',
#  'V315': 'real',
#  'V317': 'real',
#  'V322': 'int',
#  'V323': 'int',
#  'V324': 'int',
#  'V326': 'int',
#  'V331': 'real',
#  'V332': 'real',
#  'V333': 'real',
#  'V335': 'real',
#  'id_01': 'int',
#  'id_02': 'int',
#  'id_03': 'int',
#  'id_05': 'int',
#  'id_06': 'int',
#  'id_09': 'int',
#  'id_13': 'enum',
#  'id_14': 'enum',
#  'id_15': 'enum',
#  'id_16': 'enum',
#  'id_17': 'enum',
#  'id_19': 'enum',
#  'id_20': 'enum',
#  'id_30': 'enum',
#  'id_31': 'enum',
#  'id_32': 'enum',
#  'id_33': 'enum',
#  'id_38': 'enum',
#  'DeviceType': 'enum',
#  'DeviceInfo': 'enum',
#  'device_name': 'enum',
#  'OS_id_30': 'enum',
#  'version_id_30': 'enum',
#  'browser_id_31': 'enum',
#  'version_id_31': 'enum',
#  'screen_width': 'int',
#  'screen_height': 'int',
#  'P_emaildomain_bin': 'enum',
#  'P_emaildomain_suffix': 'enum',
#  'R_emaildomain_bin': 'enum',
#  'R_emaildomain_suffix': 'enum',
#  'TransactionAmt_Log': 'real',
#  'TransactionAmt_decimal': 'int',
#  'isFraud': 'enum'}

# %%
train, valid = training_hf.split_frame(ratios = [.8], seed = 1234)

# %%
rf = H2ORandomForestEstimator(model_id='rf', balance_classes = True, seed=1234)

# %%
predictors = training.columns.tolist()
predictors.remove('isFraud')
response = 'isFraud'

# %%
rf.train(x = predictors, y = response, training_frame = train, validation_frame=valid)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %%
rf.auc(train=True, valid=True)
# Out:
# {'train': 0.9948177423234049, 'valid': 0.9450383856882654}

# %%
rf.model_performance(valid)
# Out:
# ModelMetricsBinomial: drf
# ** Reported on test data. **
#
# MSE: 0.025429335318455138
# RMSE: 0.15946578102669906
# LogLoss: 0.09640666895053673
# Mean Per-Class Error: 0.12454837298149735
# AUC: 0.9450383856882654
# AUCPR: 0.6759269467133109
# Gini: 0.8900767713765307
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.0610712514651355:
#                  0       1   Error                Rate
# 0      0  112684.0  1003.0  0.0088   (1003.0/113687.0)
# 1      1    1763.0  2366.0   0.427     (1763.0/4129.0)
# 2  Total  114447.0  3369.0  0.0235   (2766.0/117816.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold          value    idx
# 0                        max f1   0.061071       0.631102  254.0
# 1                        max f2   0.033044       0.642360  288.0
# 2                  max f0point5   0.102253       0.729698  223.0
# 3                  max accuracy   0.094173       0.978288  229.0
# 4                 max precision   0.962128       1.000000    0.0
# 5                    max recall   0.000307       1.000000  397.0
# 6               max specificity   0.962128       1.000000    0.0
# 7              max absolute_mcc   0.066193       0.623089  249.0
# 8    max min_per_class_accuracy   0.015679       0.872851  324.0
# 9   max mean_per_class_accuracy   0.017142       0.875452  320.0
# 10                      max tns   0.962128  113687.000000    0.0
# 11                      max fns   0.962128    4128.000000    0.0
# 12                      max fps   0.000076  113687.000000  399.0
# 13                      max tps   0.000307    4129.000000  397.0
# 14                      max tnr   0.962128       1.000000    0.0
# 15                      max fnr   0.962128       0.999758    0.0
# 16                      max fpr   0.000076       1.000000  399.0
# 17                      max tpr   0.000307       1.000000  397.0
# Gains/Lift Table: Avg response rate:  3.50 %, avg score:  1.41 %
#     group  cumulative_data_fraction  lower_threshold       lift  \
# 0       1                  0.010007         0.214206  27.420508
# 1       2                  0.020006         0.091160  20.056005
# 2       3                  0.030004         0.057805  10.827336
# 3       4                  0.040003         0.043388   6.733780
# 4       5                  0.050002         0.035891   4.214668
# 5       6                  0.100003         0.021187   2.465404
# 6       7                  0.150005         0.015638   1.123721
# 7       8                  0.200007         0.012337   0.586078
# 8       9                  0.300002         0.008348   0.363303
# 9      10                  0.400005         0.005917   0.227650
# 10     11                  0.500000         0.004282   0.188917
# 11     12                  0.600003         0.003116   0.094451
# 12     13                  0.699998         0.002228   0.041174
# 13     14                  0.800002         0.001479   0.036327
# 14     15                  0.899997         0.000820   0.019376
# 15     16                  1.000000         0.000000   0.014531
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0         27.420508       0.960984  0.491887                  0.960984
# 1         23.739819       0.702886  0.137908                  0.831990
# 2         19.436876       0.379457  0.071661                  0.681188
# 3         16.261775       0.235993  0.049769                  0.569913
# 4         13.852763       0.147708  0.039298                  0.485486
# 5          8.159084       0.086403  0.026902                  0.285945
# 6          5.813963       0.039382  0.018142                  0.203757
# 7          4.506992       0.020540  0.013854                  0.157953
# 8          3.125840       0.012732  0.010168                  0.109549
# 9          2.401277       0.007978  0.007040                  0.084156
# 10         1.958828       0.006621  0.005055                  0.068649
# 11         1.648089       0.003310  0.003670                  0.057759
# 12         1.418541       0.001443  0.002659                  0.049714
# 13         1.245759       0.001273  0.001844                  0.043659
# 14         1.109501       0.000679  0.001148                  0.038884
# 15         1.000000       0.000509  0.000453                  0.035046
#
#     cumulative_score  capture_rate  cumulative_capture_rate         gain  \
# 0           0.491887      0.274401                 0.274401  2642.050796
# 1           0.314973      0.200533                 0.474933  1905.600537
# 2           0.233892      0.108259                 0.583192   982.733623
# 3           0.187871      0.067329                 0.650521   573.377958
# 4           0.158161      0.042141                 0.692662   321.466780
# 5           0.092532      0.123274                 0.815936   146.540431
# 6           0.067735      0.056188                 0.872124    12.372063
# 7           0.054265      0.029305                 0.901429   -41.392157
# 8           0.039567      0.036328                 0.937757   -63.669741
# 9           0.031435      0.022766                 0.960523   -77.234970
# 10          0.026159      0.018891                 0.979414   -81.108265
# 11          0.022411      0.009445                 0.988859   -90.554934
# 12          0.019589      0.004117                 0.992977   -95.882571
# 13          0.017371      0.003633                 0.996609   -96.367282
# 14          0.015569      0.001938                 0.998547   -98.062386
# 15          0.014057      0.001453                 1.000000   -98.546913
#
#     cumulative_gain  kolmogorov_smirnov
# 0       2642.050796            0.273996
# 1       2273.981893            0.471450
# 2       1843.687561            0.573279
# 3       1526.177544            0.632691
# 4       1285.276291            0.666001
# 5        715.908361            0.741935
# 6        481.396262            0.748346
# 7        350.699157            0.726897
# 8        212.584007            0.660918
# 9        140.127725            0.580876
# 10        95.882780            0.496826
# 11        64.808949            0.402979
# 12        41.854131            0.303619
# 13        24.575904            0.203748
# 14        10.950070            0.102130
# 15         0.000000            0.000000

# %%
rf.model_performance(valid).plot()

# %%
X_test.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506691 entries, 3663549 to 4170239
# Data columns (total 242 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionAmt          506691 non-null  float64
#  1   ProductCD               506691 non-null  int64
#  2   card1                   506691 non-null  int64
#  3   card2                   498037 non-null  float64
#  4   card3                   503689 non-null  float64
#  5   card4                   506691 non-null  int64
#  6   card5                   502144 non-null  float64
#  7   card6                   506691 non-null  int64
#  8   addr1                   441082 non-null  float64
#  9   addr2                   441082 non-null  float64
#  10  dist1                   215474 non-null  float64
#  11  P_emaildomain           506691 non-null  int64
#  12  R_emaildomain           506691 non-null  int64
#  13  C1                      506688 non-null  float64
#  14  C2                      506688 non-null  float64
#  15  C4                      506688 non-null  float64
#  16  C5                      506688 non-null  float64
#  17  C6                      506688 non-null  float64
#  18  C7                      506688 non-null  float64
#  19  C8                      506688 non-null  float64
#  20  C9                      506688 non-null  float64
#  21  C10                     506688 non-null  float64
#  22  C11                     506688 non-null  float64
#  23  C12                     506688 non-null  float64
#  24  C13                     501943 non-null  float64
#  25  C14                     506688 non-null  float64
#  26  D1                      500660 non-null  float64
#  27  D2                      271922 non-null  float64
#  28  D3                      303549 non-null  float64
#  29  D4                      429840 non-null  float64
#  30  D5                      282316 non-null  float64
#  31  D6                      124783 non-null  float64
#  32  D8                      74338 non-null   float64
#  33  D9                      74338 non-null   float64
#  34  D10                     494146 non-null  float64
#  35  D11                     330173 non-null  float64
#  36  D12                     69254 non-null   float64
#  37  D13                     123384 non-null  float64
#  38  D14                     115194 non-null  float64
#  39  D15                     494622 non-null  float64
#  40  M2                      506691 non-null  int64
#  41  M3                      506691 non-null  int64
#  42  M4                      506691 non-null  int64
#  43  M5                      506691 non-null  int64
#  44  M6                      506691 non-null  int64
#  45  M7                      506691 non-null  int64
#  46  M8                      506691 non-null  int64
#  47  M9                      506691 non-null  int64
#  48  V3                      330173 non-null  float64
#  135 V208                    136375 non-null  float64
#  136 V209                    136375 non-null  float64
#  137 V210                    136375 non-null  float64
#  138 V212                    136734 non-null  float64
#  139 V213                    136734 non-null  float64
#  140 V215                    136734 non-null  float64
#  141 V216                    136734 non-null  float64
#  142 V217                    126728 non-null  float64
#  143 V218                    126728 non-null  float64
#  144 V219                    126728 non-null  float64
#  145 V221                    137316 non-null  float64
#  146 V222                    137316 non-null  float64
#  147 V223                    126728 non-null  float64
#  148 V224                    126728 non-null  float64
#  149 V225                    126728 non-null  float64
#  150 V226                    126728 non-null  float64
#  151 V228                    126728 non-null  float64
#  152 V231                    126728 non-null  float64
#  153 V232                    126728 non-null  float64
#  154 V233                    126728 non-null  float64
#  155 V234                    137316 non-null  float64
#  156 V243                    126728 non-null  float64
#  157 V244                    126728 non-null  float64
#  158 V251                    137316 non-null  float64
#  159 V254                    126728 non-null  float64
#  160 V256                    137316 non-null  float64
#  161 V257                    126728 non-null  float64
#  162 V258                    126728 non-null  float64
#  163 V261                    126728 non-null  float64
#  164 V262                    126728 non-null  float64
#  165 V263                    126728 non-null  float64
#  166 V264                    126728 non-null  float64
#  167 V265                    126728 non-null  float64
#  168 V266                    126728 non-null  float64
#  169 V267                    126728 non-null  float64
#  170 V268                    126728 non-null  float64
#  171 V270                    137316 non-null  float64
#  172 V271                    137316 non-null  float64
#  173 V272                    137316 non-null  float64
#  174 V273                    126728 non-null  float64
#  175 V274                    126728 non-null  float64
#  176 V275                    126728 non-null  float64
#  177 V276                    126728 non-null  float64
#  178 V277                    126728 non-null  float64
#  179 V278                    126728 non-null  float64
#  180 V279                    506688 non-null  float64
#  181 V280                    506688 non-null  float64
#  182 V282                    500660 non-null  float64
#  183 V283                    500660 non-null  float64
#  184 V285                    506688 non-null  float64
#  185 V287                    506688 non-null  float64
#  186 V288                    500660 non-null  float64
#  187 V289                    500660 non-null  float64
#  188 V291                    506688 non-null  float64
#  189 V292                    506688 non-null  float64
#  190 V294                    506688 non-null  float64
#  191 V303                    506688 non-null  float64
#  192 V306                    506688 non-null  float64
#  193 V307                    506688 non-null  float64
#  194 V308                    506688 non-null  float64
#  195 V310                    506688 non-null  float64
#  196 V312                    506688 non-null  float64
#  197 V313                    500660 non-null  float64
#  198 V314                    500660 non-null  float64
#  199 V315                    500660 non-null  float64
#  200 V317                    506688 non-null  float64
#  201 V322                    76431 non-null   float64
#  202 V323                    76431 non-null   float64
#  203 V324                    76431 non-null   float64
#  204 V326                    76431 non-null   float64
#  205 V331                    76431 non-null   float64
#  206 V332                    76431 non-null   float64
#  207 V333                    76431 non-null   float64
#  208 V335                    76431 non-null   float64
#  209 id_01                   141907 non-null  float64
#  210 id_02                   136976 non-null  float64
#  211 id_03                   66481 non-null   float64
#  212 id_05                   134750 non-null  float64
#  213 id_06                   134750 non-null  float64
#  214 id_09                   74338 non-null   float64
#  215 id_13                   130286 non-null  float64
#  216 id_14                   71357 non-null   float64
#  217 id_15                   506691 non-null  int64
#  218 id_16                   506691 non-null  int64
#  219 id_17                   135966 non-null  float64
#  220 id_19                   135906 non-null  float64
#  221 id_20                   135633 non-null  float64
#  222 id_30                   506691 non-null  int64
#  223 id_31                   506691 non-null  int64
#  224 id_32                   70671 non-null   float64
#  225 id_33                   506691 non-null  int64
#  226 id_38                   506691 non-null  int64
#  227 DeviceType              506691 non-null  int64
#  228 DeviceInfo              506691 non-null  int64
#  229 device_name             506691 non-null  int64
#  230 OS_id_30                506691 non-null  int64
#  231 version_id_30           506691 non-null  int64
#  232 browser_id_31           506691 non-null  int64
#  233 version_id_31           506691 non-null  int64
#  234 screen_width            506691 non-null  int64
#  235 screen_height           506691 non-null  int64
#  236 P_emaildomain_bin       506691 non-null  int64
#  237 P_emaildomain_suffix    506691 non-null  int64
#  238 R_emaildomain_bin       506691 non-null  int64
#  239 R_emaildomain_suffix    506691 non-null  int64
#  240 TransactionAmt_Log      506691 non-null  float64
#  241 TransactionAmt_decimal  506691 non-null  int64
# dtypes: float64(208), int64(34)
# memory usage: 959.4 MB

# %%
X_test.fillna(-999, inplace=True)

# %%
X_test.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 506691 entries, 3663549 to 4170239
# Data columns (total 242 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionAmt          506691 non-null  float64
#  1   ProductCD               506691 non-null  int64
#  2   card1                   506691 non-null  int64
#  3   card2                   506691 non-null  float64
#  4   card3                   506691 non-null  float64
#  5   card4                   506691 non-null  int64
#  6   card5                   506691 non-null  float64
#  7   card6                   506691 non-null  int64
#  8   addr1                   506691 non-null  float64
#  9   addr2                   506691 non-null  float64
#  10  dist1                   506691 non-null  float64
#  11  P_emaildomain           506691 non-null  int64
#  12  R_emaildomain           506691 non-null  int64
#  13  C1                      506691 non-null  float64
#  14  C2                      506691 non-null  float64
#  15  C4                      506691 non-null  float64
#  16  C5                      506691 non-null  float64
#  17  C6                      506691 non-null  float64
#  18  C7                      506691 non-null  float64
#  19  C8                      506691 non-null  float64
#  20  C9                      506691 non-null  float64
#  21  C10                     506691 non-null  float64
#  22  C11                     506691 non-null  float64
#  23  C12                     506691 non-null  float64
#  24  C13                     506691 non-null  float64
#  25  C14                     506691 non-null  float64
#  26  D1                      506691 non-null  float64
#  27  D2                      506691 non-null  float64
#  28  D3                      506691 non-null  float64
#  29  D4                      506691 non-null  float64
#  30  D5                      506691 non-null  float64
#  31  D6                      506691 non-null  float64
#  32  D8                      506691 non-null  float64
#  33  D9                      506691 non-null  float64
#  34  D10                     506691 non-null  float64
#  35  D11                     506691 non-null  float64
#  36  D12                     506691 non-null  float64
#  37  D13                     506691 non-null  float64
#  38  D14                     506691 non-null  float64
#  39  D15                     506691 non-null  float64
#  40  M2                      506691 non-null  int64
#  41  M3                      506691 non-null  int64
#  42  M4                      506691 non-null  int64
#  43  M5                      506691 non-null  int64
#  44  M6                      506691 non-null  int64
#  45  M7                      506691 non-null  int64
#  46  M8                      506691 non-null  int64
#  47  M9                      506691 non-null  int64
#  48  V3                      506691 non-null  float64
#  49  V4                      506691 non-null  float64
#  50  V5                      506691 non-null  float64
#  51  V7                      506691 non-null  float64
#  52  V12                     506691 non-null  float64
#  53  V13                     506691 non-null  float64
#  54  V19                     506691 non-null  float64
#  55  V20                     506691 non-null  float64
#  56  V29                     506691 non-null  float64
#  57  V30                     506691 non-null  float64
#  58  V33                     506691 non-null  float64
#  59  V34                     506691 non-null  float64
#  60  V35                     506691 non-null  float64
#  61  V36                     506691 non-null  float64
#  62  V37                     506691 non-null  float64
#  63  V38                     506691 non-null  float64
#  64  V40                     506691 non-null  float64
#  65  V43                     506691 non-null  float64
#  66  V44                     506691 non-null  float64
#  67  V45                     506691 non-null  float64
#  68  V47                     506691 non-null  float64
#  69  V48                     506691 non-null  float64
#  70  V49                     506691 non-null  float64
#  71  V51                     506691 non-null  float64
#  72  V52                     506691 non-null  float64
#  73  V53                     506691 non-null  float64
#  74  V54                     506691 non-null  float64
#  75  V56                     506691 non-null  float64
#  76  V57                     506691 non-null  float64
#  77  V58                     506691 non-null  float64
#  78  V60                     506691 non-null  float64
#  79  V61                     506691 non-null  float64
#  80  V62                     506691 non-null  float64
#  81  V69                     506691 non-null  float64
#  82  V70                     506691 non-null  float64
#  83  V72                     506691 non-null  float64
#  84  V74                     506691 non-null  float64
#  85  V75                     506691 non-null  float64
#  86  V76                     506691 non-null  float64
#  87  V78                     506691 non-null  float64
#  88  V81                     506691 non-null  float64
#  89  V82                     506691 non-null  float64
#  90  V83                     506691 non-null  float64
#  91  V87                     506691 non-null  float64
#  92  V90                     506691 non-null  float64
#  93  V91                     506691 non-null  float64
#  94  V94                     506691 non-null  float64
#  95  V95                     506691 non-null  float64
#  96  V96                     506691 non-null  float64
#  97  V97                     506691 non-null  float64
#  98  V99                     506691 non-null  float64
#  99  V100                    506691 non-null  float64
#  100 V126                    506691 non-null  float64
#  101 V127                    506691 non-null  float64
#  102 V128                    506691 non-null  float64
#  103 V130                    506691 non-null  float64
#  104 V131                    506691 non-null  float64
#  105 V139                    506691 non-null  float64
#  106 V140                    506691 non-null  float64
#  107 V143                    506691 non-null  float64
#  108 V145                    506691 non-null  float64
#  109 V149                    506691 non-null  float64
#  110 V150                    506691 non-null  float64
#  111 V152                    506691 non-null  float64
#  112 V156                    506691 non-null  float64
#  113 V158                    506691 non-null  float64
#  114 V159                    506691 non-null  float64
#  115 V160                    506691 non-null  float64
#  116 V162                    506691 non-null  float64
#  117 V164                    506691 non-null  float64
#  118 V165                    506691 non-null  float64
#  119 V166                    506691 non-null  float64
#  120 V167                    506691 non-null  float64
#  121 V169                    506691 non-null  float64
#  122 V170                    506691 non-null  float64
#  123 V171                    506691 non-null  float64
#  124 V187                    506691 non-null  float64
#  125 V188                    506691 non-null  float64
#  126 V189                    506691 non-null  float64
#  127 V200                    506691 non-null  float64
#  128 V201                    506691 non-null  float64
#  129 V202                    506691 non-null  float64
#  130 V203                    506691 non-null  float64
#  131 V204                    506691 non-null  float64
#  132 V205                    506691 non-null  float64
#  133 V206                    506691 non-null  float64
#  134 V207                    506691 non-null  float64
#  135 V208                    506691 non-null  float64
#  136 V209                    506691 non-null  float64
#  137 V210                    506691 non-null  float64
#  138 V212                    506691 non-null  float64
#  139 V213                    506691 non-null  float64
#  140 V215                    506691 non-null  float64
#  141 V216                    506691 non-null  float64
#  142 V217                    506691 non-null  float64
#  143 V218                    506691 non-null  float64
#  144 V219                    506691 non-null  float64
#  145 V221                    506691 non-null  float64
#  146 V222                    506691 non-null  float64
#  147 V223                    506691 non-null  float64
#  148 V224                    506691 non-null  float64
#  149 V225                    506691 non-null  float64
#  150 V226                    506691 non-null  float64
#  151 V228                    506691 non-null  float64
#  152 V231                    506691 non-null  float64
#  153 V232                    506691 non-null  float64
#  154 V233                    506691 non-null  float64
#  155 V234                    506691 non-null  float64
#  156 V243                    506691 non-null  float64
#  157 V244                    506691 non-null  float64
#  158 V251                    506691 non-null  float64
#  159 V254                    506691 non-null  float64
#  160 V256                    506691 non-null  float64
#  161 V257                    506691 non-null  float64
#  162 V258                    506691 non-null  float64
#  163 V261                    506691 non-null  float64
#  164 V262                    506691 non-null  float64
#  165 V263                    506691 non-null  float64
#  166 V264                    506691 non-null  float64
#  167 V265                    506691 non-null  float64
#  168 V266                    506691 non-null  float64
#  169 V267                    506691 non-null  float64
#  170 V268                    506691 non-null  float64
#  171 V270                    506691 non-null  float64
#  172 V271                    506691 non-null  float64
#  173 V272                    506691 non-null  float64
#  174 V273                    506691 non-null  float64
#  175 V274                    506691 non-null  float64
#  176 V275                    506691 non-null  float64
#  177 V276                    506691 non-null  float64
#  178 V277                    506691 non-null  float64
#  179 V278                    506691 non-null  float64
#  180 V279                    506691 non-null  float64
#  181 V280                    506691 non-null  float64
#  182 V282                    506691 non-null  float64
#  183 V283                    506691 non-null  float64
#  184 V285                    506691 non-null  float64
#  185 V287                    506691 non-null  float64
#  186 V288                    506691 non-null  float64
#  187 V289                    506691 non-null  float64
#  188 V291                    506691 non-null  float64
#  189 V292                    506691 non-null  float64
#  190 V294                    506691 non-null  float64
#  191 V303                    506691 non-null  float64
#  192 V306                    506691 non-null  float64
#  193 V307                    506691 non-null  float64
#  194 V308                    506691 non-null  float64
#  195 V310                    506691 non-null  float64
#  196 V312                    506691 non-null  float64
#  197 V313                    506691 non-null  float64
#  198 V314                    506691 non-null  float64
#  199 V315                    506691 non-null  float64
#  200 V317                    506691 non-null  float64
#  201 V322                    506691 non-null  float64
#  202 V323                    506691 non-null  float64
#  203 V324                    506691 non-null  float64
#  204 V326                    506691 non-null  float64
#  205 V331                    506691 non-null  float64
#  206 V332                    506691 non-null  float64
#  207 V333                    506691 non-null  float64
#  208 V335                    506691 non-null  float64
#  209 id_01                   506691 non-null  float64
#  210 id_02                   506691 non-null  float64
#  211 id_03                   506691 non-null  float64
#  212 id_05                   506691 non-null  float64
#  213 id_06                   506691 non-null  float64
#  214 id_09                   506691 non-null  float64
#  215 id_13                   506691 non-null  float64
#  216 id_14                   506691 non-null  float64
#  217 id_15                   506691 non-null  int64
#  218 id_16                   506691 non-null  int64
#  219 id_17                   506691 non-null  float64
#  220 id_19                   506691 non-null  float64
#  221 id_20                   506691 non-null  float64
#  222 id_30                   506691 non-null  int64
#  223 id_31                   506691 non-null  int64
#  224 id_32                   506691 non-null  float64
#  225 id_33                   506691 non-null  int64
#  226 id_38                   506691 non-null  int64
#  227 DeviceType              506691 non-null  int64
#  228 DeviceInfo              506691 non-null  int64
#  229 device_name             506691 non-null  int64
#  230 OS_id_30                506691 non-null  int64
#  231 version_id_30           506691 non-null  int64
#  232 browser_id_31           506691 non-null  int64
#  233 version_id_31           506691 non-null  int64
#  234 screen_width            506691 non-null  int64
#  235 screen_height           506691 non-null  int64
#  236 P_emaildomain_bin       506691 non-null  int64
#  237 P_emaildomain_suffix    506691 non-null  int64
#  238 R_emaildomain_bin       506691 non-null  int64
#  239 R_emaildomain_suffix    506691 non-null  int64
#  240 TransactionAmt_Log      506691 non-null  float64
#  241 TransactionAmt_decimal  506691 non-null  int64
# dtypes: float64(208), int64(34)
# memory usage: 959.4 MB

# %%
testing_hf = h2o.H2OFrame(X_test)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
cat_var_new.remove('isFraud')

# %%
for var in cat_var_new:
    testing_hf[var] = testing_hf[var].asfactor()

# %%
testing_hf.types
# Out:
# {'TransactionAmt': 'real',
#  'ProductCD': 'enum',
#  'card1': 'enum',
#  'card2': 'enum',
#  'card3': 'enum',
#  'card4': 'enum',
#  'card5': 'enum',
#  'card6': 'enum',
#  'addr1': 'enum',
#  'addr2': 'enum',
#  'dist1': 'int',
#  'P_emaildomain': 'enum',
#  'R_emaildomain': 'enum',
#  'C1': 'int',
#  'C2': 'int',
#  'C4': 'int',
#  'C5': 'int',
#  'C6': 'int',
#  'C7': 'int',
#  'C8': 'int',
#  'C9': 'int',
#  'C10': 'int',
#  'C11': 'int',
#  'C12': 'int',
#  'C13': 'int',
#  'C14': 'int',
#  'D1': 'int',
#  'D2': 'int',
#  'D3': 'int',
#  'D4': 'int',
#  'D5': 'int',
#  'D6': 'int',
#  'D8': 'real',
#  'D9': 'real',
#  'D10': 'int',
#  'D11': 'int',
#  'D12': 'int',
#  'D13': 'int',
#  'D14': 'int',
#  'D15': 'int',
#  'M2': 'enum',
#  'M3': 'enum',
#  'M4': 'enum',
#  'M5': 'enum',
#  'M6': 'enum',
#  'M7': 'enum',
#  'M8': 'enum',
#  'M9': 'enum',
#  'V3': 'int',
#  'V4': 'int',
#  'V5': 'int',
#  'V7': 'int',
#  'V12': 'int',
#  'V13': 'int',
#  'V19': 'int',
#  'V20': 'int',
#  'V29': 'int',
#  'V30': 'int',
#  'V33': 'int',
#  'V34': 'int',
#  'V35': 'int',
#  'V36': 'int',
#  'V37': 'int',
#  'V38': 'int',
#  'V40': 'int',
#  'V43': 'int',
#  'V44': 'int',
#  'V45': 'int',
#  'V47': 'int',
#  'V48': 'int',
#  'V49': 'int',
#  'V51': 'int',
#  'V52': 'int',
#  'V53': 'int',
#  'V54': 'int',
#  'V56': 'int',
#  'V57': 'int',
#  'V58': 'int',
#  'V60': 'int',
#  'V61': 'int',
#  'V62': 'int',
#  'V69': 'int',
#  'V70': 'int',
#  'V72': 'int',
#  'V74': 'int',
#  'V75': 'int',
#  'V76': 'int',
#  'V78': 'int',
#  'V81': 'int',
#  'V82': 'int',
#  'V83': 'int',
#  'V87': 'int',
#  'V90': 'int',
#  'V91': 'int',
#  'V94': 'int',
#  'V95': 'int',
#  'V96': 'int',
#  'V97': 'int',
#  'V99': 'int',
#  'V100': 'int',
#  'V126': 'real',
#  'V127': 'real',
#  'V128': 'real',
#  'V130': 'real',
#  'V131': 'real',
#  'V139': 'int',
#  'V140': 'int',
#  'V143': 'int',
#  'V145': 'int',
#  'V149': 'int',
#  'V150': 'int',
#  'V152': 'int',
#  'V156': 'int',
#  'V158': 'int',
#  'V159': 'real',
#  'V160': 'real',
#  'V162': 'real',
#  'V164': 'real',
#  'V165': 'real',
#  'V166': 'real',
#  'V167': 'int',
#  'V169': 'int',
#  'V170': 'int',
#  'V171': 'int',
#  'V187': 'int',
#  'V188': 'int',
#  'V189': 'int',
#  'V200': 'int',
#  'V201': 'int',
#  'V202': 'real',
#  'V203': 'real',
#  'V204': 'real',
#  'V205': 'real',
#  'V206': 'real',
#  'V207': 'real',
#  'V208': 'real',
#  'V209': 'real',
#  'V210': 'real',
#  'V212': 'real',
#  'V213': 'real',
#  'V215': 'real',
#  'V216': 'real',
#  'V217': 'int',
#  'V218': 'int',
#  'V219': 'int',
#  'V221': 'int',
#  'V222': 'int',
#  'V223': 'int',
#  'V224': 'int',
#  'V225': 'int',
#  'V226': 'int',
#  'V228': 'int',
#  'V231': 'int',
#  'V232': 'int',
#  'V233': 'int',
#  'V234': 'int',
#  'V243': 'int',
#  'V244': 'int',
#  'V251': 'int',
#  'V254': 'int',
#  'V256': 'int',
#  'V257': 'int',
#  'V258': 'int',
#  'V261': 'int',
#  'V262': 'int',
#  'V263': 'real',
#  'V264': 'real',
#  'V265': 'real',
#  'V266': 'real',
#  'V267': 'real',
#  'V268': 'real',
#  'V270': 'real',
#  'V271': 'real',
#  'V272': 'real',
#  'V273': 'real',
#  'V274': 'real',
#  'V275': 'real',
#  'V276': 'real',
#  'V277': 'real',
#  'V278': 'real',
#  'V279': 'int',
#  'V280': 'int',
#  'V282': 'int',
#  'V283': 'int',
#  'V285': 'int',
#  'V287': 'int',
#  'V288': 'int',
#  'V289': 'int',
#  'V291': 'int',
#  'V292': 'int',
#  'V294': 'int',
#  'V303': 'int',
#  'V306': 'real',
#  'V307': 'real',
#  'V308': 'real',
#  'V310': 'real',
#  'V312': 'real',
#  'V313': 'real',
#  'V314': 'real',
#  'V315': 'real',
#  'V317': 'real',
#  'V322': 'int',
#  'V323': 'int',
#  'V324': 'int',
#  'V326': 'int',
#  'V331': 'real',
#  'V332': 'real',
#  'V333': 'real',
#  'V335': 'real',
#  'id_01': 'int',
#  'id_02': 'int',
#  'id_03': 'int',
#  'id_05': 'int',
#  'id_06': 'int',
#  'id_09': 'int',
#  'id_13': 'enum',
#  'id_14': 'enum',
#  'id_15': 'enum',
#  'id_16': 'enum',
#  'id_17': 'enum',
#  'id_19': 'enum',
#  'id_20': 'enum',
#  'id_30': 'enum',
#  'id_31': 'enum',
#  'id_32': 'enum',
#  'id_33': 'enum',
#  'id_38': 'enum',
#  'DeviceType': 'enum',
#  'DeviceInfo': 'enum',
#  'device_name': 'enum',
#  'OS_id_30': 'enum',
#  'version_id_30': 'enum',
#  'browser_id_31': 'enum',
#  'version_id_31': 'enum',
#  'screen_width': 'int',
#  'screen_height': 'int',
#  'P_emaildomain_bin': 'enum',
#  'P_emaildomain_suffix': 'enum',
#  'R_emaildomain_bin': 'enum',
#  'R_emaildomain_suffix': 'enum',
#  'TransactionAmt_Log': 'real',
#  'TransactionAmt_decimal': 'int'}

# %%
predict = rf.predict(testing_hf)
# Out:
# drf prediction progress: |████████████████████████████████████████████████| 100%
# /opt/conda/lib/python3.7/site-packages/h2o/job.py:70: UserWarning: Test/Validation dataset column 